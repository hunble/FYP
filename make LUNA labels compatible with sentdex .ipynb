# %%
import pandas as pd
import os

patients = os.listdir('F:\FYP Data\luna16_extracted_images')
labels_df = pd.read_csv('D:/annotations.csv',index_col=0)

Result = []
for patient in patients[:]:
    try:
        label = labels_df.get_value(patient, 'diameter_mm')
        Result.append([patient,1])
    except KeyError as e:
        Result.append([patient,0])
        
#saving labels
a= pd.DataFrame(Result,columns=['id','cancer'])
print(a)
a.to_csv('luna_labels.csv')
# Out:
#                                                     id  cancer
# 0    1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...       1
# 1    1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840...       0
# 2    1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...       1
# 3    1.3.6.1.4.1.14519.5.2.1.6279.6001.100530488926...       0
# 4    1.3.6.1.4.1.14519.5.2.1.6279.6001.100620385482...       0
# 5    1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...       1
# 6    1.3.6.1.4.1.14519.5.2.1.6279.6001.100684836163...       0
# 7    1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028...       1
# 8    1.3.6.1.4.1.14519.5.2.1.6279.6001.101228986346...       0
# 9    1.3.6.1.4.1.14519.5.2.1.6279.6001.102133688497...       0
# 10   1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408...       1
# 11   1.3.6.1.4.1.14519.5.2.1.6279.6001.103115201714...       0
# 12   1.3.6.1.4.1.14519.5.2.1.6279.6001.104562737760...       1
# 13   1.3.6.1.4.1.14519.5.2.1.6279.6001.104780906131...       0
# ...
