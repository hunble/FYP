# %%
import numpy as np

much_data1 = np.load('D:/data32/muchdata-stage1-32-32-32.npy')
much_data2 = np.load('D:/data32/muchdata-lidc-32-32-32.npy')
much_data3 = np.load('D:/data32/muchdata-luna-32-32-32.npy')

# %%
import numpy as np
much_data2 = np.load('D:/data32/muchdata-stage1-32-32-32.npy')

print(much_data2.shape)
# Out:
# (1397, 3)

# %%
kdata=[]
i=0
for data in much_data2:
    if(data[0].shape!=(32, 32, 32)):
        i=i+1
        s=[]
        print(i,len(data[0]))
        for slices in data[0]:
            s.append(slices)
        for i in range(32-len(data[0])):
            s.append(data[0][-1])
        kdata.append([s,data[1],data[2]])
    else:
        kdata.append([data[0],data[1],data[2]])
# Out:
# 1 28
# 4 29
# 3 29
# 3 27
# 5 27
# 5 29
# 3 27
# 5 27
# 5 29
# 3 27
# 5 28
# 4 27
# 5 27
# 5 27
# 5 27
# 5 29
# 3 27
# 5 27
# 5 29
# 3 28
# 4 25
# 7 29
# 3 27
# 5 28
# 4 29
# 3 28
# 4 28
# 4 29
# 3 29
# 3 29
# 3 28
# 4 28
# 4 26
# 6 28
# 4 28
# 4 28
# 4 26
# 6 27
# 5 29
# 3 29
# 3 28
# 4 27
# 5 29
# 3 27
# 5 29
# 3 28
# 4 29
# 3 28
# 4 29
# 3 28
# 4 28
# 4 28
# 4 29
# 3 28
# 4 29
# 3 29
# 3 28
# 4 29
# 3 26
# 6 27
# 5 28
# 4 27
# 5 29
# 3 29
# 3 27
# 5 26
# 6 29
# 3 29
# 3 28
# 4 29
# 3 29
# 3 29
# 3 28
# 4 27
# 5 29
# 3 26
# 6 29
# 3 29
# 3 29
# 3 28
# 4 28
# 4 27
# 5 27
# 5 29
# 3 28
# 4 29
# 3 29
# 3 29
# 3 28
# 4 27
# 5 29
# 3 28
# 4 29
# 3 28
# 4 29
# 3 27
# 5 28
# 4 27
# 5 26
# 6 28
# 4 28
# 4 29
# 3 29
# 3 28
# 4 27
# 5 26
# 6 28
# 4 29
# 3 28
# 4 27
# 5 27
# 5 28
# 4 29
# 3 29
# 3 29
# 3 26
# 6 27
# 5 27
# 5 27
# 5 28
# 4 27
# 5 28
# 4 29
# 3 27
# 5 29
# 3 29
# 3 29
# 3 28
# 4 28
# 4 29
# 3 29
# 3 28
# 4 29
# 3 29
# 3 29
# 3 28
# 4 28
# 4 29
# 3 28
# 4 28
# 4 29
# 3 28
# ...

# %%
s=much_data2[0][0]
print(much_data2[0][0].shape)
print(s.shape)
np.array(s)
s=[]
s.append([[1,2,3],[3,2,1],[1,2,3]])
print(much_data2[0][0])
# Out:
# (27, 32, 32)
# (27, 32, 32)
# [[[-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   ...,
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]]
#
#  [[-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   ...,
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]]
#
#  [[-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   ...,
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
#   [-1024. -1024. -1024. ..., -1024. -1024. -1024.]
# ...

# %%
i=0
for data in kdata[:]:
    if(np.array(data[0]).shape!=(32, 32, 32)):
        i=i+1
        print(i,data[2])

# %%
np.save('muchdata-stage11-32-32-32.npy',kdata)

# %%
abc=np.array(kdata)

# %%
print(np.array(abc[0][0]).shape)

print(much_data2[12][0].shape)
# Out:
# (32, 32, 32)
# (32, 32, 32)

# %%
print(abc[0][0][0])
# Out:
# [array([[-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#        [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#        [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#        ...,
#        [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#        [-1024., -1024., -1024., ..., -1024., -1024., -1024.],
#        [-1024., -1024., -1024., ..., -1024., -1024., -1024.]])]
